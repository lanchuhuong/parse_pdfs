# %%
# !pip install pdfservices-sdk
# !pip install openpyxl
# !pip install langchain==0.0.278
# !pip install langchain-core==0.0.11
# !pip install jsonpickle 
# %pip install -U langchain-openai
# %pip install --upgrade open-interpreter
# %pip install pytesseract
# dbutils.library.restartPython()
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: pdfservices-sdk in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: cffi==1.15.1 in /databricks/python3/lib/python3.11/site-packages (from pdfservices-sdk) (1.15.1)
# Requirement already satisfied: polling2==0.5.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.5.0)
# Requirement already satisfied: multipart==0.2.4 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.2.4)
# Requirement already satisfied: Pygments==2.14.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (2.14.0)
# Requirement already satisfied: build==0.9.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.9.0)
# Requirement already satisfied: pycparser==2.21 in /databricks/python3/lib/python3.11/site-packages (from pdfservices-sdk) (2.21)
# Requirement already satisfied: polling==0.3.2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.3.2)
# Collecting packaging==21.3
#   Using cached packaging-21.3-py3-none-any.whl (40 kB)
# Requirement already satisfied: PyYAML==6.0 in /databricks/python3/lib/python3.11/site-packages (from pdfservices-sdk) (6.0)
# Requirement already satisfied: certifi==2022.12.7 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (2022.12.7)
# Requirement already satisfied: requests==2.27.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (2.27.1)
# Requirement already satisfied: six==1.16.0 in /usr/lib/python3/dist-packages (from pdfservices-sdk) (1.16.0)
# Requirement already satisfied: pep517==0.13.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.13.0)
# Requirement already satisfied: urllib3==1.26.13 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (1.26.13)
# Requirement already satisfied: PyJWT==2.4.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (2.4.0)
# Requirement already satisfied: requests-toolbelt==0.10.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.10.1)
# Requirement already satisfied: pyparsing==3.0.9 in /databricks/python3/lib/python3.11/site-packages (from pdfservices-sdk) (3.0.9)
# Requirement already satisfied: cryptography==3.4.6 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (3.4.6)
# Requirement already satisfied: toml==0.10.2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from pdfservices-sdk) (0.10.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests==2.27.1->pdfservices-sdk) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from requests==2.27.1->pdfservices-sdk) (2.0.4)
# Installing collected packages: packaging
#   Attempting uninstall: packaging
#     Found existing installation: packaging 23.2
#     Not uninstalling packaging at /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'packaging'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.12.1 requires pyspark>=2.1.0, which is not installed.
# databricks-feature-engineering 0.3.0 requires pyspark<4,>=3.1.2, which is not installed.
# langchain-core 0.2.0 requires langsmith<0.2.0,>=0.1.0, but you have langsmith 0.0.92 which is incompatible.
# langchain-core 0.2.0 requires packaging<24.0,>=23.2, but you have packaging 21.3 which is incompatible.
# langchain-community 0.0.20 requires langchain-core<0.2,>=0.1.21, but you have langchain-core 0.2.0 which is incompatible.
# black 23.3.0 requires packaging>=22.0, but you have packaging 21.3 which is incompatible.
# Successfully installed packaging-21.3
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: openpyxl in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from openpyxl) (1.1.0)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: langchain==0.0.278 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (0.0.278)
# Requirement already satisfied: requests<3,>=2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain==0.0.278) (2.27.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain==0.0.278) (2.0.30)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.21 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain==0.0.278) (0.0.92)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /databricks/python3/lib/python3.11/site-packages (from langchain==0.0.278) (8.2.2)
# Requirement already satisfied: PyYAML>=5.3 in /databricks/python3/lib/python3.11/site-packages (from langchain==0.0.278) (6.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /databricks/python3/lib/python3.11/site-packages (from langchain==0.0.278) (3.8.5)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain==0.0.278) (0.5.14)
# Requirement already satisfied: pydantic<3,>=1 in /databricks/python3/lib/python3.11/site-packages (from langchain==0.0.278) (1.10.6)
# Requirement already satisfied: numpy<2,>=1 in /databricks/python3/lib/python3.11/site-packages (from langchain==0.0.278) (1.23.5)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain==0.0.278) (2.10.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (1.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.278) (2.0.4)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /databricks/python3/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.278) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /databricks/python3/lib/python3.11/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.278) (3.21.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /databricks/python3/lib/python3.11/site-packages (from pydantic<3,>=1->langchain==0.0.278) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.0.278) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.0.278) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langchain==0.0.278) (3.4)
# Requirement already satisfied: greenlet!=0.4.17 in /databricks/python3/lib/python3.11/site-packages (from SQLAlchemy<3,>=1.4->langchain==0.0.278) (2.0.1)
# Requirement already satisfied: packaging>=17.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.278) (21.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.278) (0.4.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.11/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.278) (3.0.9)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting langchain-core==0.0.11
#   Using cached langchain_core-0.0.11-py3-none-any.whl (181 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /databricks/python3/lib/python3.11/site-packages (from langchain-core==0.0.11) (1.33)
# Requirement already satisfied: pydantic<3,>=1 in /databricks/python3/lib/python3.11/site-packages (from langchain-core==0.0.11) (1.10.6)
# Requirement already satisfied: langsmith<0.1.0,>=0.0.63 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain-core==0.0.11) (0.0.92)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-core==0.0.11) (8.2.2)
# Requirement already satisfied: jsonpointer>=1.9 in /databricks/python3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core==0.0.11) (2.4)
# Requirement already satisfied: requests<3,>=2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langsmith<0.1.0,>=0.0.63->langchain-core==0.0.11) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /databricks/python3/lib/python3.11/site-packages (from pydantic<3,>=1->langchain-core==0.0.11) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.1.0,>=0.0.63->langchain-core==0.0.11) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.1.0,>=0.0.63->langchain-core==0.0.11) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.1.0,>=0.0.63->langchain-core==0.0.11) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from requests<3,>=2->langsmith<0.1.0,>=0.0.63->langchain-core==0.0.11) (2.0.4)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.2.0
#     Not uninstalling langchain-core at /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'langchain-core'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.1.7 requires langchain-core<0.3,>=0.1.46, but you have langchain-core 0.0.11 which is incompatible.
# langchain-community 0.0.20 requires langchain-core<0.2,>=0.1.21, but you have langchain-core 0.0.11 which is incompatible.
# Successfully installed langchain-core-0.0.11
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting jsonpickle
#   Using cached jsonpickle-3.0.4-py3-none-any.whl (39 kB)
# Installing collected packages: jsonpickle
# Successfully installed jsonpickle-3.0.4
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: langchain-openai in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (0.1.7)
# Requirement already satisfied: tiktoken<1,>=0.7 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain-openai) (0.7.0)
# Collecting langchain-core<0.3,>=0.1.46
#   Using cached langchain_core-0.2.0-py3-none-any.whl (307 kB)
# Requirement already satisfied: openai<2.0.0,>=1.24.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langchain-openai) (1.30.1)
# Collecting langsmith<0.2.0,>=0.1.0
#   Using cached langsmith-0.1.59-py3-none-any.whl (121 kB)
# Collecting packaging<24.0,>=23.2
#   Using cached packaging-23.2-py3-none-any.whl (53 kB)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /databricks/python3/lib/python3.11/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /databricks/python3/lib/python3.11/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in /databricks/python3/lib/python3.11/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (6.0)
# Requirement already satisfied: pydantic<3,>=1 in /databricks/python3/lib/python3.11/site-packages (from langchain-core<0.3,>=0.1.46->langchain-openai) (1.10.6)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.7.0)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /databricks/python3/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (0.27.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /databricks/python3/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.7.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /databricks/python3/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (3.5.0)
# Requirement already satisfied: tqdm>4 in /databricks/python3/lib/python3.11/site-packages (from openai<2.0.0,>=1.24.0->langchain-openai) (4.65.0)
# Requirement already satisfied: regex>=2022.1.18 in /databricks/python3/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.27.1)
# Requirement already satisfied: idna>=2.8 in /databricks/python3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.24.0->langchain-openai) (3.4)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (1.0.4)
# Requirement already satisfied: certifi in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (2022.12.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.24.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /databricks/python3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.46->langchain-openai) (2.4)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-core<0.3,>=0.1.46->langchain-openai) (3.10.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (1.26.13)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Installing collected packages: packaging, langsmith, langchain-core
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: langsmith
#     Found existing installation: langsmith 0.0.92
#     Not uninstalling langsmith at /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'langsmith'. No files were found to uninstall.
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.0.11
#     Uninstalling langchain-core-0.0.11:
#       Successfully uninstalled langchain-core-0.0.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.12.1 requires pyspark>=2.1.0, which is not installed.
# databricks-feature-engineering 0.3.0 requires pyspark<4,>=3.1.2, which is not installed.
# pdfservices-sdk 2.3.1 requires packaging==21.3, but you have packaging 23.2 which is incompatible.
# langchain 0.0.278 requires langsmith<0.1.0,>=0.0.21, but you have langsmith 0.1.59 which is incompatible.
# langchain-community 0.0.20 requires langchain-core<0.2,>=0.1.21, but you have langchain-core 0.2.0 which is incompatible.
# langchain-community 0.0.20 requires langsmith<0.1,>=0.0.83, but you have langsmith 0.1.59 which is incompatible.
# Successfully installed langchain-core-0.2.0 langsmith-0.1.59 packaging-23.2
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting open-interpreter
#   Using cached open_interpreter-0.2.5-py3-none-any.whl (155 kB)
# Collecting pydantic<3.0.0,>=2.6.4
#   Using cached pydantic-2.7.1-py3-none-any.whl (409 kB)
# Requirement already satisfied: six<2.0.0,>=1.16.0 in /usr/lib/python3/dist-packages (from open-interpreter) (1.16.0)
# Collecting inquirer<4.0.0,>=3.1.3
#   Using cached inquirer-3.2.4-py3-none-any.whl (18 kB)
# Collecting tiktoken<0.7.0,>=0.6.0
#   Using cached tiktoken-0.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Collecting litellm<2.0.0,>=1.34.38
#   Using cached litellm-1.37.16-py3-none-any.whl (4.4 MB)
# Collecting pyyaml<7.0.0,>=6.0.1
#   Using cached PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
# Requirement already satisfied: rich<14.0.0,>=13.4.2 in /databricks/python3/lib/python3.11/site-packages (from open-interpreter) (13.7.1)
# Collecting wget<4.0,>=3.2
#   Using cached wget-3.2-py3-none-any.whl
# Collecting posthog<4.0.0,>=3.1.0
#   Using cached posthog-3.5.0-py2.py3-none-any.whl (41 kB)
# Collecting git-python<2.0.0,>=1.0.3
#   Using cached git_python-1.0.3-py2.py3-none-any.whl (1.9 kB)
# Collecting send2trash<2.0.0,>=1.8.2
#   Using cached Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Collecting platformdirs<5.0.0,>=4.2.0
#   Using cached platformdirs-4.2.2-py3-none-any.whl (18 kB)
# Collecting html2image<3.0.0.0,>=2.0.4.3
#   Using cached html2image-2.0.4.3-py3-none-any.whl (27 kB)
# Collecting uvicorn<0.28.0,>=0.27.0
#   Using cached uvicorn-0.27.1-py3-none-any.whl (60 kB)
# Requirement already satisfied: astor<0.9.0,>=0.8.1 in /databricks/python3/lib/python3.11/site-packages (from open-interpreter) (0.8.1)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /databricks/python3/lib/python3.11/site-packages (from open-interpreter) (3.8.1)
# Collecting ipykernel<7.0.0,>=6.26.0
#   Using cached ipykernel-6.29.4-py3-none-any.whl (117 kB)
# Collecting matplotlib<4.0.0,>=3.8.2
#   Using cached matplotlib-3.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
# Collecting aifs<0.0.16,>=0.0.15
#   Using cached aifs-0.0.15-py3-none-any.whl (54 kB)
# Collecting prompt-toolkit<4.0.0,>=3.0.43
#   Using cached prompt_toolkit-3.0.43-py3-none-any.whl (386 kB)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from open-interpreter) (0.10.2)
# Collecting psutil<6.0.0,>=5.9.6
#   Using cached psutil-5.9.8-cp36-abi3-manylinux_2_12_x86_64.manylinux2010_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (288 kB)
# Collecting jupyter-client<9.0.0,>=8.6.0
#   Using cached jupyter_client-8.6.1-py3-none-any.whl (105 kB)
# Collecting fastapi<0.111.0,>=0.110.0
#   Using cached fastapi-0.110.3-py3-none-any.whl (91 kB)
# Collecting tokentrim<0.2.0,>=0.1.13
#   Using cached tokentrim-0.1.13-py3-none-any.whl (7.8 kB)
# Collecting screeninfo<0.9.0,>=0.8.1
#   Using cached screeninfo-0.8.1-py3-none-any.whl (12 kB)
# Collecting starlette<0.38.0,>=0.37.2
#   Using cached starlette-0.37.2-py3-none-any.whl (71 kB)
# Collecting typing-extensions>=4.8.0
#   Using cached typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: gitpython in /databricks/python3/lib/python3.11/site-packages (from git-python<2.0.0,>=1.0.3->open-interpreter) (3.1.27)
# Collecting websocket-client<2.0.0,>=1.0.0
#   Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Requirement already satisfied: requests in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from html2image<3.0.0.0,>=2.0.4.3->open-interpreter) (2.27.1)
# Requirement already satisfied: blessed>=1.19.0 in /databricks/python3/lib/python3.11/site-packages (from inquirer<4.0.0,>=3.1.3->open-interpreter) (1.20.0)
# Collecting readchar>=3.0.6
#   Using cached readchar-4.1.0-py3-none-any.whl (9.1 kB)
# Collecting editor>=1.6.0
#   Using cached editor-1.6.6-py3-none-any.whl (4.0 kB)
# Requirement already satisfied: ipython>=7.23.1 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (8.15.0)
# Requirement already satisfied: nest-asyncio in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (1.5.6)
# Requirement already satisfied: traitlets>=5.4.0 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.1.6)
# Requirement already satisfied: debugpy>=1.6.5 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (1.6.7)
# Requirement already satisfied: packaging in /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (23.2)
# Requirement already satisfied: tornado>=6.1 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (6.3.2)
# Requirement already satisfied: comm>=0.1.1 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.1.2)
# Collecting pyzmq>=24
#   Using cached pyzmq-26.0.3-cp311-cp311-manylinux_2_28_x86_64.whl (919 kB)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /databricks/python3/lib/python3.11/site-packages (from ipykernel<7.0.0,>=6.26.0->open-interpreter) (5.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python3/lib/python3.11/site-packages (from jupyter-client<9.0.0,>=8.6.0->open-interpreter) (2.8.2)
# Collecting requests
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Requirement already satisfied: aiohttp in /databricks/python3/lib/python3.11/site-packages (from litellm<2.0.0,>=1.34.38->open-interpreter) (3.8.5)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /databricks/python3/lib/python3.11/site-packages (from litellm<2.0.0,>=1.34.38->open-interpreter) (3.1.2)
# Requirement already satisfied: openai>=1.0.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from litellm<2.0.0,>=1.34.38->open-interpreter) (1.30.1)
# Collecting python-dotenv>=0.2.0
#   Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: tokenizers in /databricks/python3/lib/python3.11/site-packages (from litellm<2.0.0,>=1.34.38->open-interpreter) (0.15.0)
# Requirement already satisfied: click in /databricks/python3/lib/python3.11/site-packages (from litellm<2.0.0,>=1.34.38->open-interpreter) (8.0.4)
# Collecting importlib-metadata>=6.8.0
#   Using cached importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (1.23.5)
# Requirement already satisfied: contourpy>=1.0.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (4.25.0)
# Requirement already satisfied: pillow>=8 in /databricks/python3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.8.2->open-interpreter) (9.4.0)
# Requirement already satisfied: regex>=2021.8.3 in /databricks/python3/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->open-interpreter) (2022.7.9)
# Requirement already satisfied: joblib in /databricks/python3/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->open-interpreter) (1.2.0)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.11/site-packages (from nltk<4.0.0,>=3.8.1->open-interpreter) (4.65.0)
# Collecting backoff>=1.10.0
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting monotonic>=1.5
#   Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.11/site-packages (from prompt-toolkit<4.0.0,>=3.0.43->open-interpreter) (0.2.5)
# Collecting annotated-types>=0.4.0
#   Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Collecting pydantic-core==2.18.2
#   Using cached pydantic_core-2.18.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from rich<14.0.0,>=13.4.2->open-interpreter) (2.14.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /databricks/python3/lib/python3.11/site-packages (from rich<14.0.0,>=13.4.2->open-interpreter) (2.2.0)
# Requirement already satisfied: h11>=0.8 in /databricks/python3/lib/python3.11/site-packages (from uvicorn<0.28.0,>=0.27.0->open-interpreter) (0.14.0)
# Collecting runs
#   Using cached runs-1.2.2-py3-none-any.whl (7.0 kB)
# Collecting xmod
#   Using cached xmod-1.8.1-py3-none-any.whl (4.6 kB)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm<2.0.0,>=1.34.38->open-interpreter) (3.11.0)
# Requirement already satisfied: pickleshare in /databricks/python3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.7.5)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (5.1.1)
# Requirement already satisfied: backcall in /databricks/python3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /databricks/python3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (4.8.0)
# Requirement already satisfied: stack-data in /databricks/python3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /databricks/python3/lib/python3.11/site-packages (from ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.2->litellm<2.0.0,>=1.34.38->open-interpreter) (2.1.1)
# Requirement already satisfied: mdurl~=0.1 in /databricks/python3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<14.0.0,>=13.4.2->open-interpreter) (0.1.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.0.0->litellm<2.0.0,>=1.34.38->open-interpreter) (1.7.0)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.11/site-packages (from openai>=1.0.0->litellm<2.0.0,>=1.34.38->open-interpreter) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /databricks/python3/lib/python3.11/site-packages (from openai>=1.0.0->litellm<2.0.0,>=1.34.38->open-interpreter) (0.27.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /databricks/python3/lib/python3.11/site-packages (from openai>=1.0.0->litellm<2.0.0,>=1.34.38->open-interpreter) (3.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.11/site-packages (from requests->html2image<3.0.0.0,>=2.0.4.3->open-interpreter) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests->html2image<3.0.0.0,>=2.0.4.3->open-interpreter) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.11/site-packages (from requests->html2image<3.0.0.0,>=2.0.4.3->open-interpreter) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages (from requests->html2image<3.0.0.0,>=2.0.4.3->open-interpreter) (1.26.13)
# Requirement already satisfied: multidict<7.0,>=4.5 in /databricks/python3/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.34.38->open-interpreter) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /databricks/python3/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.34.38->open-interpreter) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /databricks/python3/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.34.38->open-interpreter) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.34.38->open-interpreter) (1.8.1)
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.34.38->open-interpreter) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /databricks/python3/lib/python3.11/site-packages (from aiohttp->litellm<2.0.0,>=1.34.38->open-interpreter) (1.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.11/site-packages (from gitpython->git-python<2.0.0,>=1.0.3->open-interpreter) (4.0.11)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /databricks/python3/lib/python3.11/site-packages (from tokenizers->litellm<2.0.0,>=1.34.38->open-interpreter) (0.20.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython->git-python<2.0.0,>=1.0.3->open-interpreter) (5.0.0)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.0.0->litellm<2.0.0,>=1.34.38->open-interpreter) (1.0.4)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.34.38->open-interpreter) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /databricks/python3/lib/python3.11/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers->litellm<2.0.0,>=1.34.38->open-interpreter) (2023.5.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /databricks/python3/lib/python3.11/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.11/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.7.0)
# Requirement already satisfied: asttokens in /databricks/python3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (2.0.5)
# Requirement already satisfied: pure-eval in /databricks/python3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.2.2)
# Requirement already satisfied: executing in /databricks/python3/lib/python3.11/site-packages (from stack-data->ipython>=7.23.1->ipykernel<7.0.0,>=6.26.0->open-interpreter) (0.8.3)
# Installing collected packages: wget, monotonic, xmod, websocket-client, uvicorn, typing-extensions, send2trash, screeninfo, requests, readchar, pyzmq, pyyaml, python-dotenv, psutil, prompt-toolkit, platformdirs, importlib-metadata, backoff, annotated-types, aifs, tiktoken, starlette, runs, pydantic-core, posthog, matplotlib, html2image, tokentrim, pydantic, jupyter-client, git-python, editor, ipykernel, inquirer, fastapi, litellm, open-interpreter
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 0.58.0
#     Not uninstalling websocket-client at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'websocket-client'. No files were found to uninstall.
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'typing_extensions'. No files were found to uninstall.
#   Attempting uninstall: send2trash
#     Found existing installation: Send2Trash 1.8.0
#     Not uninstalling send2trash at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'Send2Trash'. No files were found to uninstall.
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Not uninstalling requests at /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.0
#     Not uninstalling pyzmq at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'pyzmq'. No files were found to uninstall.
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Not uninstalling pyyaml at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'PyYAML'. No files were found to uninstall.
#   Attempting uninstall: psutil
#     Found existing installation: psutil 5.9.0
#     Not uninstalling psutil at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'psutil'. No files were found to uninstall.
#   Attempting uninstall: prompt-toolkit
#     Found existing installation: prompt-toolkit 3.0.36
#     Not uninstalling prompt-toolkit at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'prompt-toolkit'. No files were found to uninstall.
#   Attempting uninstall: platformdirs
#     Found existing installation: platformdirs 3.10.0
#     Not uninstalling platformdirs at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'platformdirs'. No files were found to uninstall.
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib-metadata 6.0.0
#     Not uninstalling importlib-metadata at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'importlib-metadata'. No files were found to uninstall.
#   Attempting uninstall: tiktoken
#     Found existing installation: tiktoken 0.7.0
#     Not uninstalling tiktoken at /local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'tiktoken'. No files were found to uninstall.
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.7.2
#     Not uninstalling matplotlib at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'matplotlib'. No files were found to uninstall.
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.6
#     Not uninstalling pydantic at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'pydantic'. No files were found to uninstall.
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.4.9
#     Not uninstalling jupyter-client at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'jupyter_client'. No files were found to uninstall.
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 6.25.1
#     Not uninstalling ipykernel at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311
#     Can't uninstall 'ipykernel'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# petastorm 0.12.1 requires pyspark>=2.1.0, which is not installed.
# databricks-feature-engineering 0.3.0 requires pyspark<4,>=3.1.2, which is not installed.
# pdfservices-sdk 2.3.1 requires packaging==21.3, but you have packaging 23.2 which is incompatible.
# pdfservices-sdk 2.3.1 requires PyYAML==6.0, but you have pyyaml 6.0.1 which is incompatible.
# pdfservices-sdk 2.3.1 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.
# langchain 0.0.278 requires langsmith<0.1.0,>=0.0.21, but you have langsmith 0.1.59 which is incompatible.
# langchain-openai 0.1.7 requires tiktoken<1,>=0.7, but you have tiktoken 0.6.0 which is incompatible.
# ydata-profiling 4.5.1 requires pydantic<2,>=1.8.1, but you have pydantic 2.7.1 which is incompatible.
# virtualenv 20.21.0 requires platformdirs<4,>=2.4, but you have platformdirs 4.2.2 which is incompatible.
# tensorboard 2.15.1 requires protobuf<4.24,>=3.19.6, but you have protobuf 4.24.1 which is incompatible.
# langchain-community 0.0.20 requires langchain-core<0.2,>=0.1.21, but you have langchain-core 0.2.0 which is incompatible.
# langchain-community 0.0.20 requires langsmith<0.1,>=0.0.83, but you have langsmith 0.1.59 which is incompatible.
# Successfully installed aifs-0.0.15 annotated-types-0.6.0 backoff-2.2.1 editor-1.6.6 fastapi-0.110.3 git-python-1.0.3 html2image-2.0.4.3 importlib-metadata-7.1.0 inquirer-3.2.4 ipykernel-6.29.4 jupyter-client-8.6.1 litellm-1.37.16 matplotlib-3.9.0 monotonic-1.6 open-interpreter-0.2.5 platformdirs-4.2.2 posthog-3.5.0 prompt-toolkit-3.0.43 psutil-5.9.8 pydantic-2.7.1 pydantic-core-2.18.2 python-dotenv-1.0.1 pyyaml-6.0.1 pyzmq-26.0.3 readchar-4.1.0 requests-2.31.0 runs-1.2.2 screeninfo-0.8.1 send2trash-1.8.3 starlette-0.37.2 tiktoken-0.6.0 tokentrim-0.1.13 typing-extensions-4.11.0 uvicorn-0.27.1 websocket-client-1.8.0 wget-3.2 xmod-1.8.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: pytesseract in /databricks/python3/lib/python3.11/site-packages (0.3.10)
# Requirement already satisfied: packaging>=21.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-6ff370ba-9f40-4416-adaf-ec30ad5c2311/lib/python3.11/site-packages (from pytesseract) (23.2)
# Requirement already satisfied: Pillow>=8.0.0 in /databricks/python3/lib/python3.11/site-packages (from pytesseract) (9.4.0)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
# Databricks notebook source
import base64
import json
import os
import os.path
import re
import sys
import zipfile
from datetime import datetime

import openai
import openpyxl
import pandas as pd
import tiktoken
from adobe.pdfservices.operation.auth.credentials import Credentials
from adobe.pdfservices.operation.exception.exceptions import (
    SdkException, ServiceApiException, ServiceUsageException)
from adobe.pdfservices.operation.execution_context import ExecutionContext
from adobe.pdfservices.operation.io.file_ref import FileRef
from adobe.pdfservices.operation.pdfops.extract_pdf_operation import \
    ExtractPDFOperation
from adobe.pdfservices.operation.pdfops.options.extractpdf.extract_element_type import \
    ExtractElementType
from adobe.pdfservices.operation.pdfops.options.extractpdf.extract_pdf_options import \
    ExtractPDFOptions
from adobe.pdfservices.operation.pdfops.options.extractpdf.extract_renditions_element_type import \
    ExtractRenditionsElementType
from langchain.docstore.document import Document
from langchain_openai import AzureChatOpenAI, AzureOpenAI

import requests
from langchain_openai import AzureChatOpenAI

# %% [markdown]
# ### Encode the image file and run QA pipeline

# %%
import base64
from mimetypes import guess_type
import os

import openai
from openai import OpenAI
openai.api_key = 'sk-proj-GzAIqTVMyJQFzyaewLZKT3BlbkFJUCuUsBkodR3MuS7sMX9R'
client = OpenAI(api_key = openai.api_key)
model = "gpt-4o"
# Function to encode a local image into data URL
def local_image_to_data_url(image_path):
    # Guess the MIME type of the image based on the file extension
    mime_type, _ = guess_type(image_path)
    if mime_type is None:
        mime_type = "application/octet-stream"  # Default MIME type if none is found

    # Read and encode the image file
    with open(image_path, "rb") as image_file:
        base64_encoded_data = base64.b64encode(image_file.read()).decode("utf-8")

    # Construct the data URL
    return f"data:{mime_type};base64,{base64_encoded_data}"


base_dir = 'data/raw/'
data_urls = []
responses = []
path = os.path.join(base_dir, "figures")
if os.path.isdir(path):  # Ensure it's a directory
    for image_file in os.listdir(path)[:1]:
        image_path = os.path.join(path, image_file)
        try:
            print(f"processing image: {image_path}")
            # if os.path.isfile(image_path):  # Ensure it's a file
            data_url = local_image_to_data_url(image_path)
            response = client.chat.completions.create(
            # response = client.client.create(
                model=model,
                messages=[
                    {
                        "role": "system",
                        "content": """
            You are `gpt-4-vision-preview`, the OpenAI model that is trained
            to interpret images and can describe images provided by the user
            in detail. The user has attached an image to this message for
            you to answer a question, there is definitely an image attached,
            you will never reply saying that you cannot see the image
            because the image is absolutely and always attached to this
            message. Answer the question asked by the user based on the
            image provided. Do not give any further explanation. Do not
            reply saying you can't answer the question. The answer has to be
            in a JSON format. If the image provided does not contain the
            necessary data to answer the question, return 'null' for that
            key in the JSON to ensure consistent JSON structure. 
            
            """,
                    },
                    {
                        "role": "user",
                        "content": [
                            {
                                "type": "text",
                                "text": """ 
        
            You are tasked with accurately interpreting detailed charts and
            text from the images provided to you. You will focus on extracting the price for all the DRINKS from the menu.

            Guidelines:
            - Include all the drinks in the menu
            - Do not skip any drinks in the SALAD&SOUP category
            The output must be in JSON format, with the following structure and fields strictly adhered to: 
            Response Format: 

            The output must be in JSON format, with the following structure and fields strictly adhered to: 
            - dish: the name of the appetizer dish
            - price: the price of the appetizer dish
            - currency: the currency
        
            Example of the answer:
                [{{
                "drink": "Orange Juice",
                "price": 6,
                "currency":"$"
                }},
                ]
            
                
            """,
                            },
                            {"type": "image_url", "image_url": {"url": data_url}},
                        ],
                    },
                ],
                max_tokens=3000,
            )
            content = response.choices[0].message.content

            responses.append(
                { "image": image_file, "response": content}
            )
        except Exception as e:
            print(f"error processing image {image_path}: {e}")
responses
# Out:
# processing image: /dbfs/FileStore/projects/WSsustainability/data/validation/ISA/adobe_raw/gpt-are-gpt/figures/f83e9d37272532debb6009ab38ee7450.jpg
# [{'image': 'f83e9d37272532debb6009ab38ee7450.jpg',
#   'response': '```json\n[\n    {\n        "drink": "Purified Water",\n        "price": 3.99,\n        "currency": "$"\n    },\n    {\n        "drink": "Sparkling Water",\n        "price": 3.99,\n        "currency": "$"\n    },\n    {\n        "drink": "Soda In A Bottle",\n        "price": 4.50,\n        "currency": "$"\n    },\n    {\n        "drink": "Orange Juice",\n        "price": 6.00,\n        "currency": "$"\n    },\n    {\n        "drink": "Fresh Lemonade",\n        "price": 7.50,\n        "currency": "$"\n    }\n]\n```'}]

# %% [markdown]
# ### Parsing the output

# %%
def format_output_qa(output, debug = False):
    print(f"Raw model output: {output}")
    try:
        output_text = output.replace("\n", "")
        output_text=output_text.replace("```json", "")
        output_text=output_text.replace("```", "")
        if debug is True:
            return output_text
        # Now load it into a Python dictionary
        output_dict = json.loads(output_text)
        # Flatten the dictionary
        # flat_output_dict = flatten_dict(output_dict)
        # Create a df
        df = pd.DataFrame(output_dict)
    except Exception as e:
        print(f"Error processing output: {e}")
        df = pd.DataFrame({"error": str(e)}, index=[0])
    return df

# Now process each response in the list
df_output = pd.DataFrame()
for response_dict in responses:
    response = response_dict["response"]
    df = format_output_qa(response)
    # df["company"] = response_dict["company"]
    df["image"] = response_dict["image"]
    df_output = pd.concat([df_output, df], ignore_index=True)

df_output
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>drink</th>
#       <th>price</th>
#       <th>currency</th>
#       <th>image</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Purified Water</td>
#       <td>3.99</td>
#       <td>$</td>
#       <td>f83e9d37272532debb6009ab38ee7450.jpg</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Sparkling Water</td>
#       <td>3.99</td>
#       <td>$</td>
#       <td>f83e9d37272532debb6009ab38ee7450.jpg</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Soda In A Bottle</td>
#       <td>4.50</td>
#       <td>$</td>
#       <td>f83e9d37272532debb6009ab38ee7450.jpg</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Orange Juice</td>
#       <td>6.00</td>
#       <td>$</td>
#       <td>f83e9d37272532debb6009ab38ee7450.jpg</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Fresh Lemonade</td>
#       <td>7.50</td>
#       <td>$</td>
#       <td>f83e9d37272532debb6009ab38ee7450.jpg</td>
#     </tr>
#   </tbody>
# </table>
# </div>
